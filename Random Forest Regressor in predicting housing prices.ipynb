# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['GrLivArea'], data['SalePrice'], color='blue')
plt.title('Sales Price vs Group Living Area')
plt.xlabel('Group Living Area')
plt.ylabel('Sales Price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.scatter(data['GrLivArea'], data['SalePrice'], color='blue')
#       3 plt.title('Sales Price vs Group Living Area')
#       4 plt.xlabel('Group Living Area')
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# Assuming 'train.csv' is your training data file
data = pd.read_csv('train.csv')

# Handle missing values for numerical columns
numeric_columns = data.select_dtypes(include=['number']).columns
data[numeric_columns] = data[numeric_columns].fillna(data[numeric_columns].mean())

# One-hot encode categorical variables
categorical_columns = data.select_dtypes(include=['object']).columns
data = pd.get_dummies(data, columns=categorical_columns, drop_first=True)

# Split data into features (X) and target (y)
X = data.drop('SalePrice', axis=1)
y = data['SalePrice']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['GrLivArea'], data['SalePrice'], color='blue')
plt.title('Sales Price vs Group Living Area')
plt.xlabel('Group Living Area')
plt.ylabel('Sales Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['TotalBsmtSF'], data['SalePrice'], color='blue')
plt.title('Sales Price vs Total Basement Size')
plt.xlabel('Total Basement Size')
plt.ylabel('Sales Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data['YearBuilt'], data['SalePrice'], color='blue')
plt.title('Sales Price vs Year Built')
plt.xlabel('Year Built')
plt.ylabel('Sales Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data['SalePrice'], bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Sales Price')
plt.xlabel('Sales Price')
plt.ylabel('Frequency')
plt.show()
